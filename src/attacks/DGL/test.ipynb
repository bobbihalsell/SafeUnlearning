# %%
from dgl_attack import *
from torch_dummy import *

import torch
import torch.nn as nn

# %%
class SimpleCNN(nn.Module):
    def __init__(self):
        super(SimpleCNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.fc1 = nn.Linear(64 * 8 * 8, 128)
        self.fc2 = nn.Linear(128, 10)
        self.pool = nn.MaxPool2d(2, 2)
        self.relu = nn.ReLU()
    
    def forward(self, x):
        x = self.pool(self.relu(self.conv1(x)))
        x = self.pool(self.relu(self.conv2(x)))
        x = x.view(x.size(0), -1)
        x = self.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
# 1. Import models


device = 'cuda'


model_old = torch.load("model_before_unlearning.pth", weights_only=False)
model_new = torch.load("model_after_unlearning.pth", weights_only=False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 8
#       1 # 1. Import models
#       4 device = 'cuda'
# ----> 8 model_old = torch.load("model_before_unlearning.pth", weights_only=False)
#       9 model_new = torch.load("model_after_unlearning.pth", weights_only=False)
#
# File /vol/bitbucket/vb524/dlenv/lib/python3.12/site-packages/torch/serialization.py:1471, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1469             except pickle.UnpicklingError as e:
#    1470                 raise pickle.UnpicklingError(_get_wo_message(str(e))) from None
# -> 1471         return _load(
#    1472             opened_zipfile,
#    1473             map_location,
#    1474             pickle_module,
#    1475             overall_storage=overall_storage,
#    1476             **pickle_load_args,
#    1477         )
#    1478 if mmap:
#    1479     f_name = "" if not isinstance(f, str) else f"{f}, "
#
# File /vol/bitbucket/vb524/dlenv/lib/python3.12/site-packages/torch/serialization.py:1964, in _load(zip_file, map_location, pickle_module, pickle_file, overall_storage, **pickle_load_args)
#    1962 global _serialization_tls
#    1963 _serialization_tls.map_location = map_location
# -> 1964 result = unpickler.load()
#    1965 _serialization_tls.map_location = None
#    1967 torch._utils._validate_loaded_sparse_tensors()
#
# File /vol/bitbucket/vb524/dlenv/lib/python3.12/site-packages/torch/serialization.py:1953, in _load.<locals>.UnpicklerWrapper.find_class(self, mod_name, name)
#    1951         pass
#    1952 mod_name = load_module_mapping.get(mod_name, mod_name)
# -> 1953 return super().find_class(mod_name, name)
#
# ModuleNotFoundError: No module named 'utils.toy_gradient_ascent'; 'utils' is not a package
