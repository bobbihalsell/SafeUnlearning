# %% [markdown]
# ## Step1: dataset loading

# %%
# Set the first 500 samples from CIFAR-10 class 1 as the forget set
# !PYTHONPATH=../../src python3 ../../src/datasets/main.py \
    forget=classnum \
    dataset=cifar10 \
    dataset.load_method=torchvision \
    forget.forget_idx="{1:500}" \
    +dataset.init_path=./cifar10 \
    +dataset.save_path=./data \
    dataset.cfg.batch_sizes.forget=128 \
    dataset.cfg.batch_sizes.retain=128 \
    dataset.cfg.batch_sizes.val=128 \
    experiment_name=glir_exp \
    dataset.binaries_download_dir=./artifacts
# Out:
# ============ Run Configuration ============
# dataset:
#   name: cifar10
#   num_classes: 10
#   load_method: torchvision
#   binaries_download_dir: ./artifacts
#   init_path: ./cifar10
#   save_path: ./data
#   proportion: 1
#   val_ratio: 0.2
#   forget_ratio: 0.1
#   background_ratio: 0.1
#   cfg:
#     batch_sizes:
#       retain: 128
#       forget: 128
#       val: 128
#     num_workers: 4
# forget:
#   method: classnum
#   forget_idx:
#     1: 500
# experiment_name: glir_exp
# seed: 42
#
# ...
# Clearing existing dataset save directory: ./cifar10
# Saved 60000 images to ./cifar10 in ImageFolder format.
# Clearing existing dataset split directory: ./data

# %% [markdown]
# ## Step2: Pretrained Model Loading and Unlearning

# %% [markdown]
# ### Neggradplus

# %%
# Pretrained ResNet20 model downloaded for huggingface
# !PYTHONPATH=../../src python3 ../../src/unlearning/main.py  dataset=cifar10 model=torchhub unlearner=neggradplus \
    model.repo_path=chenyaofo/pytorch-cifar-models \
    model.model_name=cifar10_resnet20 \
    dataset.save_path=./data \
    dataset.cfg.batch_sizes.forget=128 \
    dataset.cfg.batch_sizes.retain=128 \
    dataset.cfg.batch_sizes.val=128 \
    unlearner.cfg.beta=0.97 \
    unlearner.cfg.momentum=0.9 \
    unlearner.cfg.epochs=5 \
    id='001' \
    experiment_name='001'
# Out:
# ============ Run Configuration ============
# dataset:
#   name: cifar10
#   num_classes: 10
#   load_method: null
#   binaries_download_dir: null
#   init_path: null
#   save_path: ./data
#   proportion: 1
#   val_ratio: 0.2
#   forget_ratio: 0.1
#   background_ratio: 0.1
#   cfg:
#     batch_sizes:
#       retain: 128
#       forget: 128
#       val: 128
#     num_workers: 4
# model:
#   load_method: torchhub
#   repo_path: chenyaofo/pytorch-cifar-models
#   model_name: cifar10_resnet20
#   original_model_ckpt_path: null
#   unlearned_model_ckpt_path: null
# unlearner:
#   name: neggradplus
#   evaluate: true
#   cfg:
#     optimizer: sgd
#     lr: 0.001
#     momentum: 0.9
#     lr_decay_factor: null
#     epochs_per_lr_decay: null
#     weight_decay: 0.0005
#     use_l2_penalty: false
#     epochs: 5
#     beta: 0.97
# experiment_name: '001'
# output_dir: artifacts/unlearn/${experiment_name}
# seed: 42
# verbose: true
# id: '001'
#
# ...
# Using device: cuda
#  num_classes: 10
# ...

# %% [markdown]
# ### Neggrad

# %%
# !PYTHONPATH=../../src python3 ../../src/unlearning/main.py \
    dataset=cifar10 \
    model=torchhub \
    unlearner=neggrad \
    model.repo_path=chenyaofo/pytorch-cifar-models \
    model.model_name=cifar10_resnet20 \
    dataset.save_path=./data \
    dataset.cfg.batch_sizes.forget=128 \
    dataset.cfg.batch_sizes.retain=128 \
    dataset.cfg.batch_sizes.val=128 \
    unlearner.cfg.epochs=1 \
    unlearner.cfg.lr=0.005 \
    id='001' \
    experiment_name='001'
# Out:
# ============ Run Configuration ============
# dataset:
#   name: cifar10
#   num_classes: 10
#   load_method: null
#   binaries_download_dir: null
#   init_path: null
#   save_path: ./data
#   proportion: 1
#   val_ratio: 0.2
#   forget_ratio: 0.1
#   background_ratio: 0.1
#   cfg:
#     batch_sizes:
#       retain: 128
#       forget: 128
#       val: 128
#     num_workers: 4
# model:
#   load_method: torchhub
#   repo_path: chenyaofo/pytorch-cifar-models
#   model_name: cifar10_resnet20
#   original_model_ckpt_path: null
#   unlearned_model_ckpt_path: null
# unlearner:
#   name: neggrad
#   evaluate: true
#   cfg:
#     optimizer: sgd
#     lr: 0.005
#     momentum: null
#     lr_decay_factor: 0.1
#     epochs_per_lr_decay: 2
#     weight_decay: 0
#     use_l2_penalty: false
#     epochs: 1
# experiment_name: '001'
# output_dir: artifacts/unlearn/${experiment_name}
# seed: 42
# verbose: true
# id: '001'
#
# ...
# Using device: cuda
#  num_classes: 10
# Loaders loaded
# ...

# %% [markdown]
# ### Scrub

# %%
# !PYTHONPATH=../../src python3 ../../src/unlearning/main.py \
    dataset=cifar10 \
    model=torchhub \
    unlearner=scrub \
    model.repo_path=chenyaofo/pytorch-cifar-models \
    model.model_name=cifar10_resnet20 \
    dataset.save_path=./data \
    dataset.cfg.batch_sizes.forget=128 \
    dataset.cfg.batch_sizes.retain=128 \
    dataset.cfg.batch_sizes.val=128 \
    unlearner.cfg.max_epochs=2 \
    unlearner.cfg.lr=0.002 \
    id='001' \
    experiment_name='001'
# Out:
# ============ Run Configuration ============
# dataset:
#   name: cifar10
#   num_classes: 10
#   load_method: null
#   binaries_download_dir: null
#   init_path: null
#   save_path: ./data
#   proportion: 1
#   val_ratio: 0.2
#   forget_ratio: 0.1
#   background_ratio: 0.1
#   cfg:
#     batch_sizes:
#       retain: 128
#       forget: 128
#       val: 128
#     num_workers: 4
# model:
#   load_method: torchhub
#   repo_path: chenyaofo/pytorch-cifar-models
#   model_name: cifar10_resnet20
#   original_model_ckpt_path: null
#   unlearned_model_ckpt_path: null
# unlearner:
#   name: scrub
#   evaluate: true
#   cfg:
#     optimizer: sgd
#     lr: 0.002
#     lr_decay_factor: 0.1
#     epochs_per_lr_decay: 2
#     momentum: 0.9
#     weight_decay: 0.1
#     use_l2_penalty: false
#     min_epochs: 0
#     max_epochs: 2
#     alpha: 0.5
#     gamma: 0.5
#     sep_epochs: true
# experiment_name: '001'
# output_dir: artifacts/unlearn/${experiment_name}
# seed: 42
# verbose: true
# ...

# %% [markdown]
# ### Sgru

# %%
# !PYTHONPATH=../../src python3 ../../src/unlearning/main.py \
    dataset=cifar10 \
    model=torchhub \
    unlearner=sgru \
    model.repo_path=chenyaofo/pytorch-cifar-models \
    model.model_name=cifar10_resnet20 \
    dataset.save_path=./data \
    dataset.cfg.batch_sizes.forget=128 \
    dataset.cfg.batch_sizes.retain=128 \
    dataset.cfg.batch_sizes.val=128 \
    unlearner.cfg.lr=0.001 \
    unlearner.cfg.epochs=2 \
    id='001' \
    experiment_name='001'
# Out:
# ============ Run Configuration ============
# dataset:
#   name: cifar10
#   num_classes: 10
#   load_method: null
#   binaries_download_dir: null
#   init_path: null
#   save_path: ./data
#   proportion: 1
#   val_ratio: 0.2
#   forget_ratio: 0.1
#   background_ratio: 0.1
#   cfg:
#     batch_sizes:
#       retain: 128
#       forget: 128
#       val: 128
#     num_workers: 4
# model:
#   load_method: torchhub
#   repo_path: chenyaofo/pytorch-cifar-models
#   model_name: cifar10_resnet20
#   original_model_ckpt_path: null
#   unlearned_model_ckpt_path: null
# unlearner:
#   name: sgru
#   evaluate: true
#   cfg:
#     optimizer: sgd
#     lr: 0.001
#     lr_decay_factor: 0.1
#     epochs_per_lr_decay: 2
#     momentum: 0.9
#     weight_decay: 0.1
#     use_l2_penalty: false
#     epochs: 2
#     recalc_freq: 1
#     num_components: 10
#     redirection_strength: 2.5
#     max_grad_norm: 10
# experiment_name: '001'
# output_dir: artifacts/unlearn/${experiment_name}
# seed: 42
# ...

# %% [markdown]
# ## Step3: GLiR Attack

# %% [markdown]
# ### Ratio-based

# %%
# Scrub
# !PYTHONPATH=../../src python3 ../../src/attacks/GLiR/main.py  dataset=cifar10 model=torchhub attack=glir \
    experiment_name=glir_test1 \
    model.repo_path=chenyaofo/pytorch-cifar-models \
    model.model_name=cifar10_resnet20 \
    dataset.save_path=./data \
    dataset.init_path=./cifar10 \
    dataset.cfg.batch_sizes.forget=128 \
    dataset.cfg.batch_sizes.retain=128 \
    dataset.cfg.batch_sizes.val=128 \
    attack.method=ratio \
    model.original_model_ckpt_path=artifacts/unlearn/001/unlearn/scrub/cifar10_resnet20_42_original_001.pt\
    model.unlearned_model_ckpt_path=artifacts/unlearn/001/unlearn/scrub/cifar10_resnet20_42_unlearned_001.pt \
    output_dir=artifacts/unlearn/001/unlearn/scrub/ \
    +combined_roc_dir=artifacts/unlearn/001/unlearn/ratio/ \
    +plot_combined_roc=true

# neggrad
# !PYTHONPATH=../../src python3 ../../src/attacks/GLiR/main.py  dataset=cifar10 model=torchhub attack=glir \
    experiment_name=glir_test1 \
    model.repo_path=chenyaofo/pytorch-cifar-models \
    model.model_name=cifar10_resnet20 \
    dataset.save_path=./data \
    dataset.init_path=./cifar10 \
    dataset.cfg.batch_sizes.forget=128 \
    dataset.cfg.batch_sizes.retain=128 \
    dataset.cfg.batch_sizes.val=128 \
    attack.method=ratio \
    model.original_model_ckpt_path=artifacts/unlearn/001/unlearn/neggrad/cifar10_resnet20_42_original_001.pt\
    model.unlearned_model_ckpt_path=artifacts/unlearn/001/unlearn/neggrad/cifar10_resnet20_42_unlearned_001.pt \
    output_dir=artifacts/unlearn/001/unlearn/neggrad/ \
    +combined_roc_dir=artifacts/unlearn/001/unlearn/ratio/ \
    +plot_combined_roc=true

# neggradplus
# !PYTHONPATH=../../src python3 ../../src/attacks/GLiR/main.py  dataset=cifar10 model=torchhub attack=glir \
    experiment_name=glir_test1 \
    model.repo_path=chenyaofo/pytorch-cifar-models \
    model.model_name=cifar10_resnet20 \
    dataset.save_path=./data \
    dataset.init_path=./cifar10 \
    dataset.cfg.batch_sizes.forget=128 \
    dataset.cfg.batch_sizes.retain=128 \
    dataset.cfg.batch_sizes.val=128 \
    attack.method=ratio \
    model.original_model_ckpt_path=artifacts/unlearn/001/unlearn/neggradplus/cifar10_resnet20_42_original_001.pt\
    model.unlearned_model_ckpt_path=artifacts/unlearn/001/unlearn/neggradplus/cifar10_resnet20_42_unlearned_001.pt \
    output_dir=artifacts/unlearn/001/unlearn/neggradplus/ \
    +combined_roc_dir=artifacts/unlearn/001/unlearn/ratio/ \
    +plot_combined_roc=true

# sgru
# !PYTHONPATH=../../src python3 ../../src/attacks/GLiR/main.py  dataset=cifar10 model=torchhub attack=glir \
    experiment_name=glir_test1 \
    model.repo_path=chenyaofo/pytorch-cifar-models \
    model.model_name=cifar10_resnet20 \
    dataset.save_path=./data \
    dataset.init_path=./cifar10 \
    dataset.cfg.batch_sizes.forget=128 \
    dataset.cfg.batch_sizes.retain=128 \
    dataset.cfg.batch_sizes.val=128 \
    attack.method=ratio \
    model.original_model_ckpt_path=artifacts/unlearn/001/unlearn/sgru/cifar10_resnet20_42_original_001.pt\
    model.unlearned_model_ckpt_path=artifacts/unlearn/001/unlearn/sgru/cifar10_resnet20_42_unlearned_001.pt \
    output_dir=artifacts/unlearn/001/unlearn/sgru/ \
    +combined_roc_dir=artifacts/unlearn/001/unlearn/ratio/ \
    +plot_combined_roc=true
# Out:
# ============ Run Configuration ============
# dataset:
#   name: cifar10
#   num_classes: 10
#   load_method: null
#   binaries_download_dir: null
#   init_path: ./cifar10
#   save_path: ./data
#   proportion: 1
#   val_ratio: 0.2
#   forget_ratio: 0.1
#   background_ratio: 0.1
#   cfg:
#     batch_sizes:
#       retain: 128
#       forget: 128
#       val: 128
#     num_workers: 4
# model:
#   load_method: torchhub
#   repo_path: chenyaofo/pytorch-cifar-models
#   model_name: cifar10_resnet20
#   original_model_ckpt_path: artifacts/unlearn/001/unlearn/scrub/cifar10_resnet20_42_original_001.pt
#   unlearned_model_ckpt_path: artifacts/unlearn/001/unlearn/scrub/cifar10_resnet20_42_unlearned_001.pt
# attack:
#   name: glir
#   threshold: 0.2
#   num_params: 5000
#   small_var_lim: 0.01
#   test_size: null
#   method: ratio
# experiment_name: glir_test1
# output_dir: artifacts/unlearn/001/unlearn/scrub/
# seed: 42
# verbose: true
# combined_roc_dir: artifacts/unlearn/001/unlearn/ratio/
# ...

# %%
# Scrub
# !PYTHONPATH=../../src python3 ../../src/attacks/GLiR/main.py  dataset=cifar10 model=torchhub attack=glir \
    experiment_name=glir_test1 \
    model.repo_path=chenyaofo/pytorch-cifar-models \
    model.model_name=cifar10_resnet20 \
    dataset.save_path=./data \
    dataset.init_path=./cifar10 \
    dataset.cfg.batch_sizes.forget=128 \
    dataset.cfg.batch_sizes.retain=128 \
    dataset.cfg.batch_sizes.val=128 \
    attack.method=diff \
    model.original_model_ckpt_path=artifacts/unlearn/001/unlearn/scrub/cifar10_resnet20_42_original_001.pt\
    model.unlearned_model_ckpt_path=artifacts/unlearn/001/unlearn/scrub/cifar10_resnet20_42_unlearned_001.pt \
    output_dir=artifacts/unlearn/001/unlearn/scrub/ \
    +combined_roc_dir=artifacts/unlearn/001/unlearn/diff/ \
    +plot_combined_roc=true

# neggrad
# !PYTHONPATH=../../src python3 ../../src/attacks/GLiR/main.py  dataset=cifar10 model=torchhub attack=glir \
    experiment_name=glir_test1 \
    model.repo_path=chenyaofo/pytorch-cifar-models \
    model.model_name=cifar10_resnet20 \
    dataset.save_path=./data \
    dataset.init_path=./cifar10 \
    dataset.cfg.batch_sizes.forget=128 \
    dataset.cfg.batch_sizes.retain=128 \
    dataset.cfg.batch_sizes.val=128 \
    attack.method=diff \
    model.original_model_ckpt_path=artifacts/unlearn/001/unlearn/neggrad/cifar10_resnet20_42_original_001.pt\
    model.unlearned_model_ckpt_path=artifacts/unlearn/001/unlearn/neggrad/cifar10_resnet20_42_unlearned_001.pt \
    output_dir=artifacts/unlearn/001/unlearn/neggrad/ \
    +combined_roc_dir=artifacts/unlearn/001/unlearn/diff/ \
    +plot_combined_roc=true

# neggradplus
# !PYTHONPATH=../../src python3 ../../src/attacks/GLiR/main.py  dataset=cifar10 model=torchhub attack=glir \
    experiment_name=glir_test1 \
    model.repo_path=chenyaofo/pytorch-cifar-models \
    model.model_name=cifar10_resnet20 \
    dataset.save_path=./data \
    dataset.init_path=./cifar10 \
    dataset.cfg.batch_sizes.forget=128 \
    dataset.cfg.batch_sizes.retain=128 \
    dataset.cfg.batch_sizes.val=128 \
    attack.method=diff \
    model.original_model_ckpt_path=artifacts/unlearn/001/unlearn/neggradplus/cifar10_resnet20_42_original_001.pt\
    model.unlearned_model_ckpt_path=artifacts/unlearn/001/unlearn/neggradplus/cifar10_resnet20_42_unlearned_001.pt \
    output_dir=artifacts/unlearn/001/unlearn/neggradplus/ \
    +combined_roc_dir=artifacts/unlearn/001/unlearn/diff/ \
    +plot_combined_roc=true

# sgru
# !PYTHONPATH=../../src python3 ../../src/attacks/GLiR/main.py  dataset=cifar10 model=torchhub attack=glir \
    experiment_name=glir_test1 \
    model.repo_path=chenyaofo/pytorch-cifar-models \
    model.model_name=cifar10_resnet20 \
    dataset.save_path=./data \
    dataset.init_path=./cifar10 \
    dataset.cfg.batch_sizes.forget=128 \
    dataset.cfg.batch_sizes.retain=128 \
    dataset.cfg.batch_sizes.val=128 \
    attack.method=diff \
    model.original_model_ckpt_path=artifacts/unlearn/001/unlearn/sgru/cifar10_resnet20_42_original_001.pt\
    model.unlearned_model_ckpt_path=artifacts/unlearn/001/unlearn/sgru/cifar10_resnet20_42_unlearned_001.pt \
    output_dir=artifacts/unlearn/001/unlearn/sgru/ \
    +combined_roc_dir=artifacts/unlearn/001/unlearn/diff/ \
    +plot_combined_roc=true
# Out:
# ============ Run Configuration ============
# dataset:
#   name: cifar10
#   num_classes: 10
#   load_method: null
#   binaries_download_dir: null
#   init_path: ./cifar10
#   save_path: ./data
#   proportion: 1
#   val_ratio: 0.2
#   forget_ratio: 0.1
#   background_ratio: 0.1
#   cfg:
#     batch_sizes:
#       retain: 128
#       forget: 128
#       val: 128
#     num_workers: 4
# model:
#   load_method: torchhub
#   repo_path: chenyaofo/pytorch-cifar-models
#   model_name: cifar10_resnet20
#   original_model_ckpt_path: artifacts/unlearn/001/unlearn/scrub/cifar10_resnet20_42_original_001.pt
#   unlearned_model_ckpt_path: artifacts/unlearn/001/unlearn/scrub/cifar10_resnet20_42_unlearned_001.pt
# attack:
#   name: glir
#   threshold: 0.2
#   num_params: 5000
#   small_var_lim: 0.01
#   test_size: null
#   method: diff
# experiment_name: glir_test1
# output_dir: artifacts/unlearn/001/unlearn/scrub/
# seed: 42
# verbose: true
# combined_roc_dir: artifacts/unlearn/001/unlearn/diff/
# ...
