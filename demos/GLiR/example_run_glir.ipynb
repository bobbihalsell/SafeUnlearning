# %% [markdown]
# ## Step1: dataset loading

# %%
# Set the first 500 samples from CIFAR-10 class 1 as the forget set
# !PYTHONPATH=../../src python3 ../../src/datasets/main.py \
    forget=classnum \
    dataset=cifar10 \
    dataset.load_method=torchvision \
    forget.forget_idx="{1:500}" \
    +dataset.init_path=./cifar10 \
    +dataset.save_path=./data \
    dataset.cfg.batch_sizes.forget=128 \
    dataset.cfg.batch_sizes.retain=128 \
    dataset.cfg.batch_sizes.val=128 \
    experiment_name=glir_exp \
    dataset.binaries_download_dir=./artifacts
# Out:
# ============ Run Configuration ============
# dataset:
#   name: cifar10
#   num_classes: 10
#   load_method: torchvision
#   binaries_download_dir: ./artifacts
#   init_path: ./cifar10
#   save_path: ./data
#   proportion: 1
#   val_ratio: 0.2
#   forget_ratio: 0.1
#   background_ratio: 0.1
#   cfg:
#     batch_sizes:
#       retain: 128
#       forget: 128
#       val: 128
#     num_workers: 4
# forget:
#   method: classnum
#   forget_idx:
#     1: 500
# experiment_name: glir_exp
# seed: 42
#
# ============================================
# Clearing existing dataset save directory: ./cifar10
# Saved 60000 images to ./cifar10 in ImageFolder format.
# Clearing existing dataset split directory: ./data

# %% [markdown]
# ## Step2: Pretrained Model Loading and Unlearning

# %% [markdown]
# ### Neggradplus

# %%
#Pretrained ResNet20 model downloaded for huggingface 
# !PYTHONPATH=../../src python3 ../../src/unlearning/main.py  dataset=cifar10 model=torchhub unlearner=neggradplus \
    model.repo_path=chenyaofo/pytorch-cifar-models \
    model.model_name=cifar10_resnet20 \
    dataset.save_path=./data \
    dataset.cfg.batch_sizes.forget=128 \
    dataset.cfg.batch_sizes.retain=128 \
    dataset.cfg.batch_sizes.val=128 \
    unlearner.cfg.beta=0.97 \
    unlearner.cfg.momentum=0.9 \
    unlearner.cfg.epochs=4 \
    id='001' \
    experiment_name='001'
# Out:
# ============ Run Configuration ============
# dataset:
#   name: cifar10
#   num_classes: 10
#   load_method: null
#   binaries_download_dir: null
#   init_path: null
#   save_path: ./data
#   proportion: 1
#   val_ratio: 0.2
#   forget_ratio: 0.1
#   background_ratio: 0.1
#   cfg:
#     batch_sizes:
#       retain: 128
#       forget: 128
#       val: 128
#     num_workers: 4
# model:
#   load_method: torchhub
#   repo_path: chenyaofo/pytorch-cifar-models
#   model_name: cifar10_resnet20
#   original_model_ckpt_path: null
#   unlearned_model_ckpt_path: null
# unlearner:
#   name: neggradplus
#   evaluate: true
#   cfg:
#     optimizer: sgd
#     lr: 0.001
#     momentum: 0.9
#     lr_decay_factor: null
#     epochs_per_lr_decay: null
#     weight_decay: 0.0005
#     use_l2_penalty: false
#     epochs: 4
#     beta: 0.97
# experiment_name: '001'
# output_dir: artifacts/unlearn/${experiment_name}
# seed: 42
# verbose: true
# id: '001'
#
# ============================================
# Using device: cuda
#  num_classes: 10
# Loaders loaded
# Using cache found in /homes/yl28218/.cache/torch/hub/chenyaofo_pytorch-cifar-models_master
# Using cache found in /homes/yl28218/.cache/torch/hub/chenyaofo_pytorch-cifar-models_master
# Loaded model from torch.hub: chenyaofo/pytorch-cifar-models/cifar10_resnet20
# Model loaded successfully and set to evaluation mode on cuda
# Original model loaded
# Model state_dict saved to artifacts/unlearn/001/unlearn/neggradplus/cifar10_resnet20_42_original_001.pt
# Unlearning algorithm initialized.
# Initial Retain Loss: 0.0055. Acc: 99.94%. || Initial Val Loss: 0.0056. Acc: 99.96%. || Initial Forget Loss: 0.0025. Acc: 100.00%. ||
# Epoch 1 Forward Pass Complete. LR: 0.00100. Time taken: 6.7 s
# Retain Loss: 0.0196 Acc: 99.42%. Time: 6.4 s || Val Loss: 0.0225 Acc: 99.29%. Time: 1.8 s || Forget Loss: 0.1024 Acc: 97.00%. Time: 0.2 s ||
# Epoch 2 Forward Pass Complete. LR: 0.00100. Time taken: 6.7 s
# Retain Loss: 0.1056 Acc: 96.59%. Time: 7.3 s || Val Loss: 0.1235 Acc: 96.11%. Time: 1.8 s || Forget Loss: 0.5524 Acc: 94.20%. Time: 0.2 s ||
# Epoch 3 Forward Pass Complete. LR: 0.00100. Time taken: 8.0 s
# Retain Loss: 0.0634 Acc: 97.81%. Time: 7.6 s || Val Loss: 0.0711 Acc: 97.61%. Time: 2.3 s || Forget Loss: 1.3290 Acc: 93.20%. Time: 0.2 s ||
# Epoch 4 Forward Pass Complete. LR: 0.00100. Time taken: 6.9 s
# Retain Loss: 0.0621 Acc: 97.93%. Time: 6.5 s || Val Loss: 0.1071 Acc: 97.11%. Time: 2.0 s || Forget Loss: 3.6891 Acc: 89.40%. Time: 0.3 s ||
# Model unlearning complete. Time: 1.2 min
# Model state_dict saved to artifacts/unlearn/001/unlearn/neggradplus/cifar10_resnet20_42_unlearned_001.pt

# %% [markdown]
# ### Neggrad

# %%
# !PYTHONPATH=../../src python3 ../../src/unlearning/main.py \
    dataset=cifar10 \
    model=torchhub \
    unlearner=neggrad \
    model.repo_path=chenyaofo/pytorch-cifar-models \
    model.model_name=cifar10_resnet20 \
    dataset.save_path=./data \
    dataset.cfg.batch_sizes.forget=128 \
    dataset.cfg.batch_sizes.retain=128 \
    dataset.cfg.batch_sizes.val=128 \
    unlearner.cfg.epochs=1 \
    unlearner.cfg.lr=0.005 \
    id='001' \
    experiment_name='001'
# Out:
# ============ Run Configuration ============
# dataset:
#   name: cifar10
#   num_classes: 10
#   load_method: null
#   binaries_download_dir: null
#   init_path: null
#   save_path: ./data
#   proportion: 1
#   val_ratio: 0.2
#   forget_ratio: 0.1
#   background_ratio: 0.1
#   cfg:
#     batch_sizes:
#       retain: 128
#       forget: 128
#       val: 128
#     num_workers: 4
# model:
#   load_method: torchhub
#   repo_path: chenyaofo/pytorch-cifar-models
#   model_name: cifar10_resnet20
#   original_model_ckpt_path: null
#   unlearned_model_ckpt_path: null
# unlearner:
#   name: neggrad
#   evaluate: true
#   cfg:
#     optimizer: sgd
#     lr: 0.005
#     momentum: null
#     lr_decay_factor: 0.1
#     epochs_per_lr_decay: 2
#     weight_decay: 0
#     use_l2_penalty: false
#     epochs: 1
# experiment_name: '001'
# output_dir: artifacts/unlearn/${experiment_name}
# seed: 42
# verbose: true
# id: '001'
#
# ============================================
# Using device: cuda
#  num_classes: 10
# Loaders loaded
# Using cache found in /homes/yl28218/.cache/torch/hub/chenyaofo_pytorch-cifar-models_master
# Using cache found in /homes/yl28218/.cache/torch/hub/chenyaofo_pytorch-cifar-models_master
# Loaded model from torch.hub: chenyaofo/pytorch-cifar-models/cifar10_resnet20
# Model loaded successfully and set to evaluation mode on cuda
# Original model loaded
# Model state_dict saved to artifacts/unlearn/001/unlearn/neggrad/cifar10_resnet20_42_original_001.pt
# Unlearning algorithm initialized.
# Initial Retain Loss: 0.0055. Acc: 99.94%. || Initial Val Loss: 0.0056. Acc: 99.96%. || Initial Forget Loss: 0.0025. Acc: 100.00%. ||
# Epoch 1 Forward Pass Complete. LR: 0.00500. Time taken: 0.4 s
# Retain Loss: 0.0439 Acc: 98.55%. Time: 6.6 s || Val Loss: 0.0487 Acc: 98.33%. Time: 1.8 s || Forget Loss: 0.3229 Acc: 88.40%. Time: 0.2 s ||
# Model unlearning complete. Time: 0.3 min
# Model state_dict saved to artifacts/unlearn/001/unlearn/neggrad/cifar10_resnet20_42_unlearned_001.pt

# %% [markdown]
# ### Scrub

# %%
# !PYTHONPATH=../../src python3 ../../src/unlearning/main.py \
    dataset=cifar10 \
    model=torchhub \
    unlearner=scrub \
    model.repo_path=chenyaofo/pytorch-cifar-models \
    model.model_name=cifar10_resnet20 \
    dataset.save_path=./data \
    dataset.cfg.batch_sizes.forget=128 \
    dataset.cfg.batch_sizes.retain=128 \
    dataset.cfg.batch_sizes.val=128 \
    unlearner.cfg.max_epochs=3 \
    unlearner.cfg.lr=0.0015 \
    id='001' \
    experiment_name='001'
# Out:
# ============ Run Configuration ============
# dataset:
#   name: cifar10
#   num_classes: 10
#   load_method: null
#   binaries_download_dir: null
#   init_path: null
#   save_path: ./data
#   proportion: 1
#   val_ratio: 0.2
#   forget_ratio: 0.1
#   background_ratio: 0.1
#   cfg:
#     batch_sizes:
#       retain: 128
#       forget: 128
#       val: 128
#     num_workers: 4
# model:
#   load_method: torchhub
#   repo_path: chenyaofo/pytorch-cifar-models
#   model_name: cifar10_resnet20
#   original_model_ckpt_path: null
#   unlearned_model_ckpt_path: null
# unlearner:
#   name: scrub
#   evaluate: true
#   cfg:
#     optimizer: sgd
#     lr: 0.0015
#     lr_decay_factor: 0.1
#     epochs_per_lr_decay: 2
#     momentum: 0.9
#     weight_decay: 0.1
#     use_l2_penalty: false
#     min_epochs: 0
#     max_epochs: 3
#     alpha: 0.5
#     gamma: 0.5
#     sep_epochs: true
# experiment_name: '001'
# output_dir: artifacts/unlearn/${experiment_name}
# seed: 42
# verbose: true
# id: '001'
#
# ============================================
# Using device: cuda
#  num_classes: 10
# Loaders loaded
# Using cache found in /homes/yl28218/.cache/torch/hub/chenyaofo_pytorch-cifar-models_master
# Using cache found in /homes/yl28218/.cache/torch/hub/chenyaofo_pytorch-cifar-models_master
# Loaded model from torch.hub: chenyaofo/pytorch-cifar-models/cifar10_resnet20
# Model loaded successfully and set to evaluation mode on cuda
# Original model loaded
# Model state_dict saved to artifacts/unlearn/001/unlearn/scrub/cifar10_resnet20_42_original_001.pt
# Unlearning algorithm initialized.
# Initial Retain Loss: 0.0055. Acc: 99.94%. || Initial Val Loss: 0.0056. Acc: 99.96%. || Initial Forget Loss: 0.0025. Acc: 100.00%. ||
# Epoch 1 Forward Pass Complete. LR: 0.00150. Time taken: 0.5 s
# Retain Loss: 0.0054 Acc: 99.95%. Time: 6.6 s || Val Loss: 0.0055 Acc: 99.94%. Time: 1.9 s || Forget Loss: 0.0030 Acc: 100.00%. Time: 0.2 s ||
# Epoch 2 Forward Pass Complete. LR: 0.00150. Time taken: 0.3 s
# Retain Loss: 0.0073 Acc: 99.91%. Time: 6.6 s || Val Loss: 0.0074 Acc: 99.90%. Time: 1.8 s || Forget Loss: 0.0201 Acc: 99.20%. Time: 0.2 s ||
# Epoch 3 Forward Pass Complete. LR: 0.00015. Time taken: 0.3 s
# Retain Loss: 0.0275 Acc: 99.13%. Time: 7.2 s || Val Loss: 0.0295 Acc: 99.02%. Time: 1.7 s || Forget Loss: 0.1856 Acc: 93.80%. Time: 0.2 s ||
# Model unlearning complete. Time: 0.6 min
# Model state_dict saved to artifacts/unlearn/001/unlearn/scrub/cifar10_resnet20_42_unlearned_001.pt

# %% [markdown]
# ### Sgru

# %%
# !PYTHONPATH=../../src python3 ../../src/unlearning/main.py \
    dataset=cifar10 \
    model=torchhub \
    unlearner=sgru \
    model.repo_path=chenyaofo/pytorch-cifar-models \
    model.model_name=cifar10_resnet20 \
    dataset.save_path=./data \
    dataset.cfg.batch_sizes.forget=128 \
    dataset.cfg.batch_sizes.retain=128 \
    dataset.cfg.batch_sizes.val=128 \
    unlearner.cfg.lr=0.0008 \
    unlearner.cfg.epochs=3 \
    id='001' \
    experiment_name='001'
# Out:
# ============ Run Configuration ============
# dataset:
#   name: cifar10
#   num_classes: 10
#   load_method: null
#   binaries_download_dir: null
#   init_path: null
#   save_path: ./data
#   proportion: 1
#   val_ratio: 0.2
#   forget_ratio: 0.1
#   background_ratio: 0.1
#   cfg:
#     batch_sizes:
#       retain: 128
#       forget: 128
#       val: 128
#     num_workers: 4
# model:
#   load_method: torchhub
#   repo_path: chenyaofo/pytorch-cifar-models
#   model_name: cifar10_resnet20
#   original_model_ckpt_path: null
#   unlearned_model_ckpt_path: null
# unlearner:
#   name: sgru
#   evaluate: true
#   cfg:
#     optimizer: sgd
#     lr: 0.0008
#     lr_decay_factor: 0.1
#     epochs_per_lr_decay: 2
#     momentum: 0.9
#     weight_decay: 0.1
#     use_l2_penalty: false
#     epochs: 3
#     recalc_freq: 1
#     num_components: 10
#     redirection_strength: 2.5
#     max_grad_norm: 10
# experiment_name: '001'
# output_dir: artifacts/unlearn/${experiment_name}
# seed: 42
# verbose: true
# id: '001'
#
# ============================================
# Using device: cuda
#  num_classes: 10
# Loaders loaded
# Using cache found in /homes/yl28218/.cache/torch/hub/chenyaofo_pytorch-cifar-models_master
# Using cache found in /homes/yl28218/.cache/torch/hub/chenyaofo_pytorch-cifar-models_master
# Loaded model from torch.hub: chenyaofo/pytorch-cifar-models/cifar10_resnet20
# Model loaded successfully and set to evaluation mode on cuda
# Original model loaded
# Model state_dict saved to artifacts/unlearn/001/unlearn/sgru/cifar10_resnet20_42_original_001.pt
# Unlearning algorithm initialized.
# Initial Retain Loss: 0.0055. Acc: 99.94%. || Initial Val Loss: 0.0056. Acc: 99.96%. || Initial Forget Loss: 0.0025. Acc: 100.00%. ||
# Epoch 1 Forward Pass Complete. LR: 0.00080. Time taken: 9.1 s
# Retain Loss: 0.0378 Acc: 99.83%. Time: 6.9 s || Val Loss: 0.0420 Acc: 99.60%. Time: 2.3 s || Forget Loss: 0.0732 Acc: 97.80%. Time: 0.3 s ||
# Epoch 2 Forward Pass Complete. LR: 0.00080. Time taken: 9.4 s
# Retain Loss: 0.2860 Acc: 93.62%. Time: 6.8 s || Val Loss: 0.3094 Acc: 92.59%. Time: 2.2 s || Forget Loss: 1.0213 Acc: 67.00%. Time: 0.3 s ||
# Epoch 3 Forward Pass Complete. LR: 0.00008. Time taken: 8.6 s
# Retain Loss: 0.1939 Acc: 98.08%. Time: 7.7 s || Val Loss: 0.2153 Acc: 97.07%. Time: 1.8 s || Forget Loss: 0.5302 Acc: 86.80%. Time: 0.3 s ||
# Model unlearning complete. Time: 1.1 min
# Model state_dict saved to artifacts/unlearn/001/unlearn/sgru/cifar10_resnet20_42_unlearned_001.pt

# %% [markdown]
# ## Step3: GLiR Attack

# %% [markdown]
# ### Ratio-based

# %%
#Scrub
# !PYTHONPATH=../../src python3 ../../src/attacks/GLiR/main.py  dataset=cifar10 model=torchhub attack=glir \
    experiment_name=glir_test1 \
    model.repo_path=chenyaofo/pytorch-cifar-models \
    model.model_name=cifar10_resnet20 \
    dataset.save_path=./data \
    dataset.init_path=./cifar10 \
    dataset.cfg.batch_sizes.forget=128 \
    dataset.cfg.batch_sizes.retain=128 \
    dataset.cfg.batch_sizes.val=128 \
    model.original_model_ckpt_path=artifacts/unlearn/001/unlearn/scrub/cifar10_resnet20_42_original_001.pt\
    model.unlearned_model_ckpt_path=artifacts/unlearn/001/unlearn/scrub/cifar10_resnet20_42_unlearned_001.pt \
    +combined_roc_dir=artifacts/unlearn/001/unlearn/ \
    +plot_combined_roc=true
# Out:
# ============ Run Configuration ============
# dataset:
#   name: cifar10
#   num_classes: 10
#   load_method: null
#   binaries_download_dir: null
#   init_path: ./cifar10
#   save_path: ./data
#   proportion: 1
#   val_ratio: 0.2
#   forget_ratio: 0.1
#   background_ratio: 0.1
#   cfg:
#     batch_sizes:
#       retain: 128
#       forget: 128
#       val: 128
#     num_workers: 4
# model:
#   load_method: torchhub
#   repo_path: chenyaofo/pytorch-cifar-models
#   model_name: cifar10_resnet20
#   original_model_ckpt_path: artifacts/unlearn/001/unlearn/scrub/cifar10_resnet20_42_original_001.pt
#   unlearned_model_ckpt_path: artifacts/unlearn/001/unlearn/scrub/cifar10_resnet20_42_unlearned_001.pt
# attack:
#   name: glir
#   threshold: 0.2
#   num_params: 5000
#   small_var_lim: 0.01
#   test_size: null
#   method: diff
# experiment_name: glir_test1
# output_dir: artifacts/attacks/${experiment_name}
# seed: 42
# verbose: true
# combined_roc_dir: artifacts/unlearn/001/unlearn/
# plot_combined_roc: true
#
# ============================================
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_require', '_validate_attack_params', '_validate_class_params', '_validate_dataset_params', '_validate_model_params', '_validate_required_sections', '_validate_timm_params', '_validate_torchhub_params', '_validate_torchvision_params', '_validate_unlearner_params', '_validate_wandb_params', 'attack_file', 'background_ratio', 'combined_roc_dir', 'config', 'dataset_file', 'dataset_name', 'dataset_save_dir', 'experiment_name', 'init_path', 'initialise_attack', 'initialise_baseline', 'initialise_data', 'load_method', 'method', 'model_ckpt_path', 'model_file', 'model_kwargs', 'model_name', 'num_classes', 'num_params', 'original_model_ckpt_path', 'output_dir', 'perform_attack', 'plot_combined_roc', 'pretrained', 'run', 'seed', 'small_var_lim', 'test_size', 'threshold', 'unlearned_model_ckpt_path', 'verbose', 'wandb_enabled']
# Using device: cuda
# Peparing query points and background points...
# Error executing job with overrides: ['dataset=cifar10', 'model=torchhub', 'attack=glir', 'experiment_name=glir_test1', 'model.repo_path=chenyaofo/pytorch-cifar-models', 'model.model_name=cifar10_resnet20', 'dataset.save_path=./data', 'dataset.init_path=./cifar10', 'dataset.cfg.batch_sizes.forget=128', 'dataset.cfg.batch_sizes.retain=128', 'dataset.cfg.batch_sizes.val=128', 'model.original_model_ckpt_path=artifacts/unlearn/001/unlearn/scrub/cifar10_resnet20_42_original_001.pt', 'model.unlearned_model_ckpt_path=artifacts/unlearn/001/unlearn/scrub/cifar10_resnet20_42_unlearned_001.pt', '+combined_roc_dir=artifacts/unlearn/001/unlearn/', '+plot_combined_roc=true']
# Traceback (most recent call last):
#   File "/vol/bitbucket/yl28218/safe-unlearning/demos/GLiR/../../src/attacks/GLiR/main.py", line 244, in main
#     app.run()
#   File "/vol/bitbucket/yl28218/safe-unlearning/demos/GLiR/../../src/attacks/GLiR/main.py", line 213, in run
#     self.initialise_data()
#   File "/vol/bitbucket/yl28218/safe-unlearning/demos/GLiR/../../src/attacks/GLiR/main.py", line 58, in initialise_data
#     self.dataset_init_dir,
#     ^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'GLiRApp' object has no attribute 'dataset_init_dir'. Did you mean: 'dataset_save_dir'?
#
# Set the environment variable HYDRA_FULL_ERROR=1 for a complete stack trace.
